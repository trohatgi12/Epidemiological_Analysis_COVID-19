# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import csv
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('data/Compiled_Data.csv')
df.head()
# Out:
#    Unnamed: 0  Case no. Report date Date of onset Gender Age  \
# 0           0         1   23/1/2020     21/1/2020      M  39
# 1           1         2   23/1/2020     18/1/2020      M  56
# 2           2         3   24/1/2020     20/1/2020      F  62
# 3           3         4   24/1/2020     23/1/2020      F  62
# 4           4         5   24/1/2020     23/1/2020      M  63
#
#     Name of hospital admitted Hospitalised/Discharged/Deceased  \
# 0  Princess Margaret Hospital                       Discharged
# 1  Princess Margaret Hospital                       Discharged
# 2  Princess Margaret Hospital                       Discharged
# 3  Princess Margaret Hospital                       Discharged
# 4  Princess Margaret Hospital                       Discharged
#
#   HK/Non-HK resident Case classification* Confirmed/probable  \
# 0    Non-HK resident             Imported          Confirmed
# 1        HK resident             Imported          Confirmed
# 2    Non-HK resident             Imported          Confirmed
# 3    Non-HK resident             Imported          Confirmed
# 4    Non-HK resident             Imported          Confirmed
#
#                     Residence Area of Residence  \
# 0  Princess Margaret Hospital        Kwai Tsing
# 1         Tower 1A, Oceanaire            Shatin
# 2             South Hillcrest          Tuen Mun
# 3        Tower 1, Lake Silver            Shatin
# 4        Tower 1, Lake Silver            Shatin
#
#                                              Geocode Occupation  \
# 0  Princess Margaret Hospital, 2-10 Princess Marg...        NaN
# 1  Oceanaire Tower 1a, 18 Po Tai St, Ma On Shan, ...        NaN
# 2  South Hillcrest, 3 Tuen Kwai Rd, Tuen Mun, Hon...        NaN
# 3  Lake Silver Tower 1, 599 Sai Sha Rd, Lake Silv...        NaN
# 4  Lake Silver Tower 1, 599 Sai Sha Rd, Lake Silv...        NaN
#
#   Travel History Relationship with other patients Remarks Cluster  \
# 0            NaN                              NaN     NaN     NaN
# 1            NaN                              NaN     NaN     NaN
# 2            NaN                              NaN     NaN     NaN
# 3            NaN                              NaN     NaN     NaN
# 4            NaN                              NaN     NaN     NaN
#
#                                   Combined Address
# 0  Princess Margaret Hospital Kwai Tsing Hong Kong
# 1             Tower 1A, Oceanaire Shatin Hong Kong
# 2               South Hillcrest Tuen Mun Hong Kong
# 3            Tower 1, Lake Silver Shatin Hong Kong
# 4            Tower 1, Lake Silver Shatin Hong Kong

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
genderCount = df.groupby('Gender')['Case no.'].nunique()
genderCount
# Out:
# Gender
# F    431
# M    505
# Name: Case no., dtype: int64

# %%
import matplotlib as mpl
dpi = 100
mpl.rcParams['figure.dpi']= dpi

# %%
labels = 'Male', 'Female'
sizes = [505,431]
explode = (0,0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Gender Distribution of COVID-19, Hong Kong')
ax1.legend()
plt.savefig('img/gender_pie.png')
plt.show()
