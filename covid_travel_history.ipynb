# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/clustered_data.csv')
df.head()
# Out:
#    Unnamed: 0  Case no. Report date Date of onset Gender Age  \
# 0           0         1   23/1/2020     21/1/2020      M  39
# 1           1         2   23/1/2020     18/1/2020      M  56
# 2           2         3   24/1/2020     20/1/2020      F  62
# 3           3         4   24/1/2020     23/1/2020      F  62
# 4           4         5   24/1/2020     23/1/2020      M  63
#
#     Name of hospital admitted Hospitalised/Discharged/Deceased  \
# 0  Princess Margaret Hospital                       Discharged
# 1  Princess Margaret Hospital                       Discharged
# 2  Princess Margaret Hospital                       Discharged
# 3  Princess Margaret Hospital                       Discharged
# 4  Princess Margaret Hospital                       Discharged
#
#   HK/Non-HK resident Case classification*  ...                    Geocode  \
# 0    Non-HK resident             Imported  ...  (22.3415435, 114.1338324)
# ...

# %%
pd.options.display.max_rows = 4000
li = df['Travel History'].value_counts()
li
# Out:
# UK                                                 102
# -                                                   55
# UK/London                                           35
# London                                              26
# United Kingdom                                      24
# USA                                                 12
# France                                               9
# United States                                        5
# Philippines                                          4
# US                                                   4
# Switzerland                                          4
# Canada                                               4
# Argentina, Brazil, Chile                             3
# Dubai                                                3
# Finland, Singapore, Swissland                        3
# New York                                             3
# Thailand                                             3
# ...

# %%
len(li)
# Out:
# 144

# %%
df['Case classification*'].value_counts()
# Out:
# Imported                                538
# Close contact of local case             166
# Possibly local                           99
# Local case                               64
# Close contact of possibly local case     48
# Close contact of imported case           21
# Name: Case classification*, dtype: int64
